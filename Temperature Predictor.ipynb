# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score

import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import callbacks

import tensorflow as tf

# %%
import math
from typing import Optional, Union, Tuple

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/jena-climate-2009-2016/jena_climate_2009_2016.csv

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %% [markdown]
# ## Helper Functions

# %%
def create_sliding_window(features: np.ndarray, target: np.ndarray, window_size: int) -> Tuple[np.ndarray, np.ndarray]:
    """
    Creates sliding windows for the given data to provide context for LSTM Prediction.

    Args:
        features (np.ndarray): Input feature values.
        target (np.ndarray): Target values.
        window_size (int): Size of the sliding window.

    Retruns:
        Tuple[np.ndarray, np.ndarray]
    """

    X, y = [], []
    total_length = len(features)

    for i in range(total_length - window_size):
        X.append(features[i:i+window_size])
        y.append(target[i + window_size])

    return (np.array(X), np.array(y))

# %%
def prepare_train_test_datasets(
    df: pd.DataFrame,
    test_split: Optional[float],
    window_size: int,
    feature_scaler: Optional[StandardScaler] = None,
    target_scaler: Optional[StandardScaler] = None
) -> Union[
    Tuple[int, np.ndarray, np.ndarray, np.ndarray, np.ndarray, StandardScaler, StandardScaler],
    Tuple[np.ndarray, np.ndarray, StandardScaler]
]:
    """
    Prepare the training and validation datasets. Or prepare the test dataset.
    Depends upon the test_split parameter.

    Args:
        df (pd.DataFrame): Input dataframe.
        test_split (float, optional): Fraction of data used for validation. If None, treats input as test data.
        window_size (int): Size of the sliding window.
        feature_scaler (StandardScaler, optional): Pre-fitted feature scaler (for test).
        target_scaler (StandardScaler, optional): Pre-fitted target scaler (for test).

    Returns:
        Union[
            Tuple[int, np.ndarray, np.ndarray, np.ndarray, np.ndarray, StandardScaler, StandardScaler],
            Tuple[np.ndarray, np.ndarray]
        ]

        if test_split is None: Returns training_data_len, X_train, y_train, X_val, y_val, feature_scaler, target_scaler
        else: Returns X_test, y_test
    """
    
    features = df.drop(columns=['T (degC)']).values
    target = df['T (degC)'].values.reshape(-1, 1)

    if test_split is not None:
        training_data_len = int(np.ceil((1 - test_split) * len(features)))

        # Initialize Scaler and Fit Transform entire dataset
        feature_scaler = StandardScaler()
        target_scaler = StandardScaler()

        scaled_features = feature_scaler.fit_transform(features)
        scaled_target = target_scaler.fit_transform(target)

        scaled_features_train = scaled_features[:training_data_len]
        scaled_target_train = scaled_target[:training_data_len]

        X_train, y_train = create_sliding_window(scaled_features_train, scaled_target_train, window_size)

        scaled_features_val = scaled_features[training_data_len - window_size:]
        scaled_target_val = scaled_target[training_data_len - window_size:]

        X_val, y_val = create_sliding_window(scaled_features_val, scaled_target_val, window_size)

        return training_data_len, X_train, y_train, X_val, y_val, feature_scaler, target_scaler

    else:
        assert feature_scaler is not None and target_scaler is not None, "Scalers must be provided when test_split is None"

        scaled_features_test = feature_scaler.transform(features)
        scaled_target_test = target_scaler.transform(target)

        X_test, y_test = create_sliding_window(scaled_features_test, scaled_target_test, window_size)

        return X_test, y_test

# %%
def build_model(X_train: np.ndarray, learning_rate: float) -> keras.Model:
    """
    Builds and compiles the Deep Learning model.

    Args:
        X_train (np.ndarray): Training data.
        learning_rate (float): Learning Rate for the optimizer.

    Retruns:
        keras.Model: Compiled Keras model.
    """

    model = models.Sequential(name="ImprovedTempPredictor")
    
    model.add(layers.Input(shape=(X_train.shape[1], X_train.shape[2])))
    model.add(layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True)))
    model.add(layers.BatchNormalization())

    model.add(layers.Bidirectional(layers.LSTM(32)))
    model.add(layers.BatchNormalization())

    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(1))

    model.compile(
        optimizer=optimizers.Adam(learning_rate=learning_rate),
        loss='mae',
        metrics=['root_mean_squared_error', 'r2_score']
    )
    
    model.summary()
    
    return model

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv("/kaggle/input/jena-climate-2009-2016/jena_climate_2009_2016.csv")
df = df[5::6]

date_time = pd.to_datetime(df.pop('Date Time'), format='%d.%m.%Y %H:%M:%S')

# %%
df.head()
# Out:
#     p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 17    996.84     -8.81    264.59        -9.66    93.5          3.13
# 23    996.99     -9.05    264.34       -10.02    92.6          3.07
# 29    997.46     -9.63    263.72       -10.65    92.2          2.94
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 5           3.14          0.19       1.96             3.15       1307.86
# 11          2.90          0.21       1.81             2.91       1312.25
# 17          2.93          0.20       1.83             2.94       1312.18
# 23          2.85          0.23       1.78             2.85       1313.61
# 29          2.71          0.23       1.69             2.71       1317.19
#
#     wv (m/s)  max. wv (m/s)  wd (deg)
# 5       0.21           0.63     192.7
# 11      0.25           0.63     190.3
# 17      0.18           0.63     167.2
# 23      0.10           0.38     240.0
# 29      0.40           0.88     157.0

# %% [markdown]
# ## Clean Dataset

# %%
cleaned_df = df.copy()

# Add engineered time features
cleaned_df['Month'] = date_time.dt.month
cleaned_df['Week'] = date_time.dt.isocalendar().week
cleaned_df['Year'] = date_time.dt.year
 
cleaned_df.dropna(inplace=True)

# %%
cleaned_df.head()
# Out:
#     p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 17    996.84     -8.81    264.59        -9.66    93.5          3.13
# 23    996.99     -9.05    264.34       -10.02    92.6          3.07
# 29    997.46     -9.63    263.72       -10.65    92.2          2.94
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 5           3.14          0.19       1.96             3.15       1307.86
# 11          2.90          0.21       1.81             2.91       1312.25
# 17          2.93          0.20       1.83             2.94       1312.18
# 23          2.85          0.23       1.78             2.85       1313.61
# 29          2.71          0.23       1.69             2.71       1317.19
#
#     wv (m/s)  max. wv (m/s)  wd (deg)  Month  Week  Year
# 5       0.21           0.63     192.7      1     1  2009
# 11      0.25           0.63     190.3      1     1  2009
# 17      0.18           0.63     167.2      1     1  2009
# 23      0.10           0.38     240.0      1     1  2009
# 29      0.40           0.88     157.0      1     1  2009

# %% [markdown]
# #### A very clean periodic trend can be noticed with temperature, relative humidity along the years.

# %%
plot_cols = ['T (degC)', 'p (mbar)', 'rho (g/m**3)']
plot_features = cleaned_df[plot_cols]
plot_features.index = date_time
_ = plot_features.plot(subplots=True, figsize=(10,6))

# %% [markdown]
# ## Feature Engineering

# %%
cleaned_df.describe().transpose()
# Out:
#                    count         mean        std      min      25%     50%  \
# p (mbar)         70091.0   989.212842   8.358886    913.6    984.2  989.57
# T (degC)         70091.0     9.450482   8.423384   -22.76     3.35    9.41
# Tpot (K)         70091.0   283.493086   8.504424   250.85   277.44  283.46
# Tdew (degC)      70091.0     4.956471   6.730081    -24.8     0.24    5.21
# rh (%)           70091.0    76.009788   16.47492    13.88    65.21    79.3
# VPmax (mbar)     70091.0    13.576576   7.739883     0.97     7.77   11.82
# VPact (mbar)     70091.0     9.533968   4.183658     0.81     6.22    8.86
# VPdef (mbar)     70091.0     4.042536   4.898549      0.0     0.87    2.19
# sh (g/kg)        70091.0      6.02256   2.655812     0.51     3.92    5.59
# H2OC (mmol/mol)  70091.0     9.640437   4.234862     0.81     6.29    8.96
# rho (g/m**3)     70091.0  1216.061232  39.974263  1059.45  1187.47  1213.8
# wv (m/s)         70091.0     1.702567  65.447512  -9999.0     0.99    1.76
# max. wv (m/s)    70091.0     2.963041  75.597657  -9999.0     1.76    2.98
# wd (deg)         70091.0   174.789095  86.619431      0.0    125.3   198.1
# Month            70091.0     6.517427   3.448298      1.0      4.0     7.0
# Week             70091.0    26.618211  15.060558      1.0     14.0    27.0
# Year             70091.0  2012.496826    2.28976   2009.0   2010.0  2012.0
#
#                       75%      max
# p (mbar)           994.72  1015.29
# T (degC)            15.48    37.28
# Tpot (K)           289.53   311.21
# Tdew (degC)         10.08    23.06
# rh (%)               89.4    100.0
# VPmax (mbar)        17.61    63.77
# VPact (mbar)        12.36    28.25
# VPdef (mbar)          5.3    46.01
# sh (g/kg)             7.8    18.07
# H2OC (mmol/mol)     12.49    28.74
# rho (g/m**3)     1242.765  1393.54
# wv (m/s)             2.86    14.01
# max. wv (m/s)        4.74     23.5
# wd (deg)            234.0    360.0
# Month                10.0     12.0
# Week                 40.0     53.0
# Year               2014.0   2016.0

# %%
## Remove Outlier / Erroneous Values

cleaned_df.loc[-9999.0, 'wv (m/s)'] = 0.0
cleaned_df.loc[-9999.0, 'max. wv (m/s)'] = 0.0

# %% [markdown]
# #### Since Wind Direction is in degrees, convert them Wind Velocity and Max Wind Velocity columns to vectors

# %%
wv = cleaned_df.pop('wv (m/s)')
max_wv = cleaned_df.pop('max. wv (m/s)')

# Convert to radians.
wd_rad = cleaned_df.pop('wd (deg)') * np.pi / 180

# Calculate the wind x and y components.
cleaned_df['Wx'] = wv * np.cos(wd_rad)
cleaned_df['Wy'] = wv * np.sin(wd_rad)

# Calculate the max wind x and y components.
cleaned_df['max Wx'] = max_wv * np.cos(wd_rad)
cleaned_df['max Wy'] = max_wv * np.sin(wd_rad)

# %%
cleaned_df.head()
# Out:
#     p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 17    996.84     -8.81    264.59        -9.66    93.5          3.13
# 23    996.99     -9.05    264.34       -10.02    92.6          3.07
# 29    997.46     -9.63    263.72       -10.65    92.2          2.94
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 5           3.14          0.19       1.96             3.15       1307.86
# 11          2.90          0.21       1.81             2.91       1312.25
# 17          2.93          0.20       1.83             2.94       1312.18
# 23          2.85          0.23       1.78             2.85       1313.61
# 29          2.71          0.23       1.69             2.71       1317.19
#
#     Month  Week    Year        Wx        Wy    max Wx    max Wy
# 5     1.0     1  2009.0 -0.204862 -0.046168 -0.614587 -0.138503
# 11    1.0     1  2009.0 -0.245971 -0.044701 -0.619848 -0.112645
# 17    1.0     1  2009.0 -0.175527  0.039879 -0.614344  0.139576
# 23    1.0     1  2009.0 -0.050000 -0.086603 -0.190000 -0.329090
# 29    1.0     1  2009.0 -0.368202  0.156292 -0.810044  0.343843

# %% [markdown]
# #### Both DayOfYear (1–365) and Hour (0–23) are cyclical.
#
# #### Neural nets don’t naturally understand that 23:00 and 00:00 are close in time.
#
# #### By encoding them as sine/cosine vectors, you map them onto a circle — preserving cyclic proximity.

# %%
timestamp_s = date_time.map(pd.Timestamp.timestamp)

day = 24*60*60
year = (365.2425)*day

cleaned_df['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
cleaned_df['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
cleaned_df['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
cleaned_df['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

# %%
cleaned_df.head()
# Out:
#     p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 17    996.84     -8.81    264.59        -9.66    93.5          3.13
# 23    996.99     -9.05    264.34       -10.02    92.6          3.07
# 29    997.46     -9.63    263.72       -10.65    92.2          2.94
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  ...  Week    Year  \
# 5           3.14          0.19       1.96             3.15  ...     1  2009.0
# 11          2.90          0.21       1.81             2.91  ...     1  2009.0
# 17          2.93          0.20       1.83             2.94  ...     1  2009.0
# 23          2.85          0.23       1.78             2.85  ...     1  2009.0
# 29          2.71          0.23       1.69             2.71  ...     1  2009.0
#
#           Wx        Wy    max Wx    max Wy   Day sin   Day cos  Year sin  \
# 5  -0.204862 -0.046168 -0.614587 -0.138503  0.258819  0.965926  0.010049
# 11 -0.245971 -0.044701 -0.619848 -0.112645  0.500000  0.866025  0.010766
# 17 -0.175527  0.039879 -0.614344  0.139576  0.707107  0.707107  0.011483
# 23 -0.050000 -0.086603 -0.190000 -0.329090  0.866025  0.500000  0.012199
# 29 -0.368202  0.156292 -0.810044  0.343843  0.965926  0.258819  0.012916
#
#     Year cos
# 5   0.999950
# 11  0.999942
# 17  0.999934
# 23  0.999926
# 29  0.999917
#
# [5 rows x 22 columns]

# %%
plt.plot(cleaned_df['Day sin'][:25])
plt.plot(cleaned_df['Day cos'][:25])
plt.xlabel('Time [h]')
plt.title('Time of day signal')
# Out:
# Text(0.5, 1.0, 'Time of day signal')

# %%
cleaned_df.dropna(inplace=True)
cleaned_df.isna().sum()
# Out:
# p (mbar)           0
# T (degC)           0
# Tpot (K)           0
# Tdew (degC)        0
# rh (%)             0
# VPmax (mbar)       0
# VPact (mbar)       0
# VPdef (mbar)       0
# sh (g/kg)          0
# H2OC (mmol/mol)    0
# rho (g/m**3)       0
# Month              0
# Week               0
# Year               0
# Wx                 0
# Wy                 0
# max Wx             0
# max Wy             0
# Day sin            0
# Day cos            0
# Year sin           0
# Year cos           0
# dtype: int64

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Create Train and Validation Datasets

# %%
n = len(df)

train_and_val_df = cleaned_df[0:int(n*0.9)]

# %%
training_data_len, X_train, y_train, X_val, y_val, feature_scaler, target_scaler = prepare_train_test_datasets(train_and_val_df, 0.2, 24)

# %%
# Hyperparameters
batch_size = 128
epochs = 100
learning_rate = 0.001

# Build model
model = build_model(X_train, learning_rate)

# Early stopping to avoid overfitting
early_stop = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Reduce learning rate to avoid overshooting and plateuing
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1,
    min_lr=1e-6
)

# Fit model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop, reduce_lr],
    verbose=2
)
# Out:
# I0000 00:00:1747986798.557630    1106 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1747986798.558266    1106 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "ImprovedTempPredictor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 24, 64)              │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 24, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 24, 128)             │          66,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 116,609 (455.50 KB)
#  Trainable params: 116,097 (453.50 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/100
# I0000 00:00:1747986806.897468    1162 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 395/395 - 15s - 39ms/step - loss: 0.2671 - r2_score: 0.8620 - root_mean_squared_error: 0.3792 - val_loss: 0.1497 - val_r2_score: 0.9578 - val_root_mean_squared_error: 0.1866 - learning_rate: 0.0010
# Epoch 2/100
# 395/395 - 5s - 14ms/step - loss: 0.1661 - r2_score: 0.9535 - root_mean_squared_error: 0.2201 - val_loss: 0.0989 - val_r2_score: 0.9802 - val_root_mean_squared_error: 0.1278 - learning_rate: 0.0010
# Epoch 3/100
# 395/395 - 5s - 14ms/step - loss: 0.1488 - r2_score: 0.9621 - root_mean_squared_error: 0.1988 - val_loss: 0.0893 - val_r2_score: 0.9835 - val_root_mean_squared_error: 0.1166 - learning_rate: 0.0010
# Epoch 4/100
# 395/395 - 5s - 14ms/step - loss: 0.1380 - r2_score: 0.9669 - root_mean_squared_error: 0.1858 - val_loss: 0.0926 - val_r2_score: 0.9831 - val_root_mean_squared_error: 0.1180 - learning_rate: 0.0010
# Epoch 5/100
# 395/395 - 6s - 14ms/step - loss: 0.1313 - r2_score: 0.9696 - root_mean_squared_error: 0.1780 - val_loss: 0.0895 - val_r2_score: 0.9833 - val_root_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 6/100
# 395/395 - 6s - 14ms/step - loss: 0.1312 - r2_score: 0.9691 - root_mean_squared_error: 0.1794 - val_loss: 0.0719 - val_r2_score: 0.9886 - val_root_mean_squared_error: 0.0968 - learning_rate: 0.0010
# Epoch 7/100
# 395/395 - 6s - 14ms/step - loss: 0.1284 - r2_score: 0.9702 - root_mean_squared_error: 0.1761 - val_loss: 0.0824 - val_r2_score: 0.9844 - val_root_mean_squared_error: 0.1133 - learning_rate: 0.0010
# Epoch 8/100
# 395/395 - 6s - 14ms/step - loss: 0.1248 - r2_score: 0.9718 - root_mean_squared_error: 0.1713 - val_loss: 0.0711 - val_r2_score: 0.9890 - val_root_mean_squared_error: 0.0951 - learning_rate: 0.0010
# Epoch 9/100
# 395/395 - 5s - 14ms/step - loss: 0.1231 - r2_score: 0.9727 - root_mean_squared_error: 0.1688 - val_loss: 0.0943 - val_r2_score: 0.9813 - val_root_mean_squared_error: 0.1242 - learning_rate: 0.0010
# Epoch 10/100
# 395/395 - 5s - 14ms/step - loss: 0.1217 - r2_score: 0.9730 - root_mean_squared_error: 0.1678 - val_loss: 0.0686 - val_r2_score: 0.9896 - val_root_mean_squared_error: 0.0925 - learning_rate: 0.0010
# Epoch 11/100
# 395/395 - 5s - 14ms/step - loss: 0.1202 - r2_score: 0.9738 - root_mean_squared_error: 0.1651 - val_loss: 0.0688 - val_r2_score: 0.9895 - val_root_mean_squared_error: 0.0932 - learning_rate: 0.0010
# Epoch 12/100
# 395/395 - 6s - 14ms/step - loss: 0.1224 - r2_score: 0.9727 - root_mean_squared_error: 0.1688 - val_loss: 0.0900 - val_r2_score: 0.9835 - val_root_mean_squared_error: 0.1165 - learning_rate: 0.0010
# Epoch 13/100
# 395/395 - 6s - 14ms/step - loss: 0.1203 - r2_score: 0.9736 - root_mean_squared_error: 0.1657 - val_loss: 0.0797 - val_r2_score: 0.9864 - val_root_mean_squared_error: 0.1061 - learning_rate: 0.0010
# Epoch 14/100
# 395/395 - 5s - 14ms/step - loss: 0.1205 - r2_score: 0.9732 - root_mean_squared_error: 0.1671 - val_loss: 0.0875 - val_r2_score: 0.9835 - val_root_mean_squared_error: 0.1167 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 395/395 - 5s - 14ms/step - loss: 0.1184 - r2_score: 0.9744 - root_mean_squared_error: 0.1632 - val_loss: 0.0708 - val_r2_score: 0.9888 - val_root_mean_squared_error: 0.0961 - learning_rate: 0.0010
# Epoch 16/100
# 395/395 - 5s - 14ms/step - loss: 0.1129 - r2_score: 0.9763 - root_mean_squared_error: 0.1572 - val_loss: 0.0592 - val_r2_score: 0.9913 - val_root_mean_squared_error: 0.0848 - learning_rate: 5.0000e-04
# Epoch 17/100
# 395/395 - 5s - 14ms/step - loss: 0.1121 - r2_score: 0.9767 - root_mean_squared_error: 0.1559 - val_loss: 0.0711 - val_r2_score: 0.9893 - val_root_mean_squared_error: 0.0941 - learning_rate: 5.0000e-04
# Epoch 18/100
# 395/395 - 5s - 14ms/step - loss: 0.1112 - r2_score: 0.9770 - root_mean_squared_error: 0.1548 - val_loss: 0.0621 - val_r2_score: 0.9909 - val_root_mean_squared_error: 0.0868 - learning_rate: 5.0000e-04
# Epoch 19/100
# 395/395 - 6s - 14ms/step - loss: 0.1100 - r2_score: 0.9775 - root_mean_squared_error: 0.1531 - val_loss: 0.0717 - val_r2_score: 0.9888 - val_root_mean_squared_error: 0.0960 - learning_rate: 5.0000e-04
# Epoch 20/100
# 395/395 - 5s - 14ms/step - loss: 0.1105 - r2_score: 0.9773 - root_mean_squared_error: 0.1537 - val_loss: 0.0811 - val_r2_score: 0.9867 - val_root_mean_squared_error: 0.1047 - learning_rate: 5.0000e-04
# Epoch 21/100
# 395/395 - 5s - 14ms/step - loss: 0.1097 - r2_score: 0.9777 - root_mean_squared_error: 0.1523 - val_loss: 0.0585 - val_r2_score: 0.9915 - val_root_mean_squared_error: 0.0839 - learning_rate: 5.0000e-04
# Epoch 22/100
# 395/395 - 6s - 14ms/step - loss: 0.1090 - r2_score: 0.9777 - root_mean_squared_error: 0.1525 - val_loss: 0.0746 - val_r2_score: 0.9882 - val_root_mean_squared_error: 0.0988 - learning_rate: 5.0000e-04
# Epoch 23/100
# 395/395 - 5s - 14ms/step - loss: 0.1089 - r2_score: 0.9778 - root_mean_squared_error: 0.1520 - val_loss: 0.0585 - val_r2_score: 0.9915 - val_root_mean_squared_error: 0.0837 - learning_rate: 5.0000e-04
# Epoch 24/100
# 395/395 - 6s - 14ms/step - loss: 0.1088 - r2_score: 0.9780 - root_mean_squared_error: 0.1515 - val_loss: 0.0631 - val_r2_score: 0.9907 - val_root_mean_squared_error: 0.0875 - learning_rate: 5.0000e-04
# Epoch 25/100
# 395/395 - 5s - 14ms/step - loss: 0.1088 - r2_score: 0.9779 - root_mean_squared_error: 0.1517 - val_loss: 0.0577 - val_r2_score: 0.9916 - val_root_mean_squared_error: 0.0833 - learning_rate: 5.0000e-04
# Epoch 26/100
# 395/395 - 6s - 14ms/step - loss: 0.1085 - r2_score: 0.9781 - root_mean_squared_error: 0.1511 - val_loss: 0.0577 - val_r2_score: 0.9918 - val_root_mean_squared_error: 0.0820 - learning_rate: 5.0000e-04
# Epoch 27/100
# 395/395 - 5s - 14ms/step - loss: 0.1075 - r2_score: 0.9783 - root_mean_squared_error: 0.1504 - val_loss: 0.0783 - val_r2_score: 0.9872 - val_root_mean_squared_error: 0.1026 - learning_rate: 5.0000e-04
# Epoch 28/100
# 395/395 - 6s - 14ms/step - loss: 0.1083 - r2_score: 0.9780 - root_mean_squared_error: 0.1514 - val_loss: 0.0563 - val_r2_score: 0.9920 - val_root_mean_squared_error: 0.0814 - learning_rate: 5.0000e-04
# Epoch 29/100
# 395/395 - 5s - 14ms/step - loss: 0.1079 - r2_score: 0.9782 - root_mean_squared_error: 0.1508 - val_loss: 0.0626 - val_r2_score: 0.9909 - val_root_mean_squared_error: 0.0868 - learning_rate: 5.0000e-04
# Epoch 30/100
# 395/395 - 6s - 14ms/step - loss: 0.1074 - r2_score: 0.9784 - root_mean_squared_error: 0.1500 - val_loss: 0.0625 - val_r2_score: 0.9907 - val_root_mean_squared_error: 0.0878 - learning_rate: 5.0000e-04
# Epoch 31/100
# 395/395 - 5s - 14ms/step - loss: 0.1075 - r2_score: 0.9784 - root_mean_squared_error: 0.1501 - val_loss: 0.0624 - val_r2_score: 0.9905 - val_root_mean_squared_error: 0.0885 - learning_rate: 5.0000e-04
# Epoch 32/100
# 395/395 - 6s - 14ms/step - loss: 0.1066 - r2_score: 0.9787 - root_mean_squared_error: 0.1491 - val_loss: 0.0574 - val_r2_score: 0.9917 - val_root_mean_squared_error: 0.0828 - learning_rate: 5.0000e-04
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 395/395 - 5s - 14ms/step - loss: 0.1063 - r2_score: 0.9787 - root_mean_squared_error: 0.1488 - val_loss: 0.0565 - val_r2_score: 0.9918 - val_root_mean_squared_error: 0.0824 - learning_rate: 5.0000e-04
# Epoch 34/100
# 395/395 - 5s - 14ms/step - loss: 0.1042 - r2_score: 0.9793 - root_mean_squared_error: 0.1469 - val_loss: 0.0550 - val_r2_score: 0.9922 - val_root_mean_squared_error: 0.0804 - learning_rate: 2.5000e-04
# Epoch 35/100
# 395/395 - 5s - 14ms/step - loss: 0.1044 - r2_score: 0.9793 - root_mean_squared_error: 0.1467 - val_loss: 0.0555 - val_r2_score: 0.9922 - val_root_mean_squared_error: 0.0800 - learning_rate: 2.5000e-04
# Epoch 36/100
# 395/395 - 6s - 14ms/step - loss: 0.1030 - r2_score: 0.9800 - root_mean_squared_error: 0.1445 - val_loss: 0.0557 - val_r2_score: 0.9922 - val_root_mean_squared_error: 0.0801 - learning_rate: 2.5000e-04
# Epoch 37/100
# 395/395 - 5s - 14ms/step - loss: 0.1035 - r2_score: 0.9797 - root_mean_squared_error: 0.1454 - val_loss: 0.0561 - val_r2_score: 0.9921 - val_root_mean_squared_error: 0.0809 - learning_rate: 2.5000e-04
# Epoch 38/100
# 395/395 - 5s - 14ms/step - loss: 0.1033 - r2_score: 0.9799 - root_mean_squared_error: 0.1447 - val_loss: 0.0562 - val_r2_score: 0.9922 - val_root_mean_squared_error: 0.0802 - learning_rate: 2.5000e-04
# Epoch 39/100
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 395/395 - 5s - 14ms/step - loss: 0.1032 - r2_score: 0.9799 - root_mean_squared_error: 0.1447 - val_loss: 0.0589 - val_r2_score: 0.9916 - val_root_mean_squared_error: 0.0831 - learning_rate: 2.5000e-04
# Epoch 40/100
# 395/395 - 5s - 14ms/step - loss: 0.1025 - r2_score: 0.9801 - root_mean_squared_error: 0.1441 - val_loss: 0.0565 - val_r2_score: 0.9921 - val_root_mean_squared_error: 0.0807 - learning_rate: 1.2500e-04
# Epoch 41/100
# 395/395 - 5s - 14ms/step - loss: 0.1023 - r2_score: 0.9801 - root_mean_squared_error: 0.1440 - val_loss: 0.0574 - val_r2_score: 0.9918 - val_root_mean_squared_error: 0.0820 - learning_rate: 1.2500e-04
# Epoch 42/100
# 395/395 - 6s - 14ms/step - loss: 0.1024 - r2_score: 0.9801 - root_mean_squared_error: 0.1439 - val_loss: 0.0584 - val_r2_score: 0.9919 - val_root_mean_squared_error: 0.0819 - learning_rate: 1.2500e-04
# Epoch 43/100
# 395/395 - 5s - 14ms/step - loss: 0.1022 - r2_score: 0.9801 - root_mean_squared_error: 0.1441 - val_loss: 0.0588 - val_r2_score: 0.9916 - val_root_mean_squared_error: 0.0831 - learning_rate: 1.2500e-04
# Epoch 44/100
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 395/395 - 5s - 14ms/step - loss: 0.1019 - r2_score: 0.9801 - root_mean_squared_error: 0.1440 - val_loss: 0.0550 - val_r2_score: 0.9923 - val_root_mean_squared_error: 0.0797 - learning_rate: 1.2500e-04
# Epoch 45/100
# 395/395 - 5s - 14ms/step - loss: 0.1012 - r2_score: 0.9805 - root_mean_squared_error: 0.1426 - val_loss: 0.0563 - val_r2_score: 0.9920 - val_root_mean_squared_error: 0.0811 - learning_rate: 6.2500e-05
# Epoch 46/100
# 395/395 - 5s - 14ms/step - loss: 0.1018 - r2_score: 0.9803 - root_mean_squared_error: 0.1434 - val_loss: 0.0597 - val_r2_score: 0.9916 - val_root_mean_squared_error: 0.0834 - learning_rate: 6.2500e-05
# Epoch 47/100
# 395/395 - 6s - 14ms/step - loss: 0.1009 - r2_score: 0.9806 - root_mean_squared_error: 0.1422 - val_loss: 0.0604 - val_r2_score: 0.9914 - val_root_mean_squared_error: 0.0844 - learning_rate: 6.2500e-05
# Epoch 48/100
# 395/395 - 6s - 14ms/step - loss: 0.1010 - r2_score: 0.9805 - root_mean_squared_error: 0.1427 - val_loss: 0.0564 - val_r2_score: 0.9921 - val_root_mean_squared_error: 0.0807 - learning_rate: 6.2500e-05
# Epoch 49/100
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 395/395 - 6s - 14ms/step - loss: 0.1018 - r2_score: 0.9803 - root_mean_squared_error: 0.1432 - val_loss: 0.0577 - val_r2_score: 0.9919 - val_root_mean_squared_error: 0.0816 - learning_rate: 6.2500e-05
# Epoch 50/100
# 395/395 - 6s - 14ms/step - loss: 0.1009 - r2_score: 0.9804 - root_mean_squared_error: 0.1430 - val_loss: 0.0591 - val_r2_score: 0.9916 - val_root_mean_squared_error: 0.0832 - learning_rate: 3.1250e-05
# Epoch 51/100
# 395/395 - 5s - 14ms/step - loss: 0.1012 - r2_score: 0.9804 - root_mean_squared_error: 0.1428 - val_loss: 0.0596 - val_r2_score: 0.9916 - val_root_mean_squared_error: 0.0833 - learning_rate: 3.1250e-05
# Epoch 52/100
# 395/395 - 5s - 14ms/step - loss: 0.1006 - r2_score: 0.9806 - root_mean_squared_error: 0.1420 - val_loss: 0.0569 - val_r2_score: 0.9920 - val_root_mean_squared_error: 0.0810 - learning_rate: 3.1250e-05
# Epoch 53/100
# 395/395 - 6s - 14ms/step - loss: 0.1003 - r2_score: 0.9806 - root_mean_squared_error: 0.1422 - val_loss: 0.0564 - val_r2_score: 0.9921 - val_root_mean_squared_error: 0.0806 - learning_rate: 3.1250e-05
# Epoch 54/100
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 395/395 - 6s - 14ms/step - loss: 0.1006 - r2_score: 0.9807 - root_mean_squared_error: 0.1417 - val_loss: 0.0596 - val_r2_score: 0.9915 - val_root_mean_squared_error: 0.0836 - learning_rate: 3.1250e-05
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 44.

# %% [markdown]
# ## Training History and Prediction Graphs

# %%
def generate_history_graph(history: dict) -> None:
    """
        Plots History Graph.

        Args:
            history (dict): History Dictionary from Keras model training.

        Returns:
            None
    """

    metrics = list(history.history.keys())
    num_metrics = len(metrics)
    cols = 2
    rows = math.ceil(num_metrics / cols)

    plt.figure(figsize=(8 * cols, 6 * rows))

    for idx, metric in enumerate(metrics, 1):
        plt.subplot(rows, cols, idx)
        plt.plot(history.history[metric], label=metric)
        plt.title(f"{metric} over Epochs")
        plt.xlabel('Epochs')
        plt.ylabel(metric)
        plt.legend()
        plt.grid(True)

    plt.tight_layout()
    plt.show()

generate_history_graph(history)

# %%
def generate_prediction_graph(
    X: np.ndarray, 
    y: np.ndarray, 
    target_scaler: StandardScaler, 
    is_test=False
) -> Optional[Tuple[np.ndarray, np.ndarray]]:
    """
        Plots Prediction Graph on the Validation/Test Dataset.
        Depends upon the is_test parameter.

        Args:
            X & y (np.ndarray): Input features and target.
            target_scaler (StandardScaler): Scaler to inverse transform predictions.
            is_test (bool): If True, indicates test dataset.

        Returns:
            Optional[Tuple[np.ndarray, np.ndarray]]: y_true and y_pred if is_test=True
    """

    y_pred_scaled = model.predict(X)

    # 2. Inverse scale to original units
    y_pred = target_scaler.inverse_transform(y_pred_scaled)
    y_true = target_scaler.inverse_transform(y)
    
    # 3. Plot first 100 samples or full range
    plt.figure(figsize=(12,6))
    plt.plot(y_true[::250], label='Actual Temperature')
    plt.plot(y_pred[::250], label='Predicted Temperature')
    plt.xlabel('Time Step')
    plt.ylabel('Temperature (°C)')
    plt.title(f"Actual vs Predicted Temperature on {'Test' if is_test else 'Validation'} Set")
    plt.legend()
    plt.show()

    if is_test:
        return y_true, y_pred


generate_prediction_graph(X_val, y_val, target_scaler)
# Out:
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
test_df = cleaned_df[int(n*0.9):]

X_test, y_test = prepare_train_test_datasets(test_df, None, 60, feature_scaler, target_scaler)

y_true, y_pred = generate_prediction_graph(X_test, y_test, target_scaler, True)
# Out:
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
y_pred_rounded = np.round(y_pred, 2)

comparison_array = np.concatenate([y_true[::20], y_pred_rounded[::20]], axis=1)
comparison_df = pd.DataFrame(comparison_array, columns=['Actual_Temperature', 'Predicted_Temperature'])

# %%
comparison_df.head()
# Out:
#    Actual_Temperature  Predicted_Temperature
# 0               -0.72                  -0.62
# 1                0.32                   0.00
# 2                2.15                   1.72
# 3                5.72                   5.12
# 4               11.00                  10.55

# %% [markdown]
# ## Metrics

# %%
mae = mean_absolute_error(y_true, y_pred_rounded)
rmse = np.sqrt(mean_squared_error(y_true, y_pred_rounded))

print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
# MAE: 0.5129
# RMSE: 0.7255

# %%
r2 = r2_score(y_true, y_pred_rounded)
print(f"R^2 score: {r2:.4f}")
# Out:
# R^2 score: 0.9914

# %% [markdown]
# ## Save Model

# %%
model.save('TempPredictor.keras')
