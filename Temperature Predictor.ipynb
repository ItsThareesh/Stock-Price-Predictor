# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import callbacks

# %%
import math
from typing import Optional, Tuple

# %% [markdown]
# ## Helper Functions

# %%
def create_sliding_window(features: np.ndarray, target: np.ndarray, window_size: int) -> Tuple[np.ndarray, np.ndarray]:
    """
    Creates sliding windows for the given data to provide context for LSTM Prediction.

    Args:
        features (np.ndarray): Input feature values.
        target (np.ndarray): Target values.
        window_size (int): Size of the sliding window.

    Retruns:
        Tuple[np.ndarray, np.ndarray]
    """

    X, y = [], []
    total_length = len(features)

    for i in range(total_length - window_size):
        X.append(features[i:i+window_size])
        y.append(target[i + window_size])

    return (np.array(X), np.array(y))

# %%
def prepare_train_test_datasets(
    df: pd.DataFrame,
    test_split: Optional[float],
    window_size: int,
) -> Tuple[int, np.ndarray, np.ndarray, np.ndarray, np.ndarray, StandardScaler]:
    """
    Prepare the training and validation datasets.

    Args:
        df (pd.DataFrame): DataFrame containing the data.
        test_split (float): Fraction of data to be used for validation.
        window_size (int): Size of the sliding window.

    Returns:
        Tuple[int, np.ndarray, np.ndarray, np.ndarray, np.ndarray, StandardScaler]
    """
    
    features = df.drop(columns=['T (degC)']).values
    target = df['T (degC)'].values.reshape(-1, 1)

    training_data_len = int(np.ceil((1 - test_split) * len(features)))

    # Initialize Scaler and Fit Transform entire dataset
    feature_scaler = StandardScaler()
    target_scaler = StandardScaler()

    scaled_features = feature_scaler.fit_transform(features)
    scaled_target = target_scaler.fit_transform(target)

    scaled_train = scaled_features[:training_data_len]
    target_train = scaled_target[:training_data_len]

    X_train, y_train = create_sliding_window(scaled_train, target_train, window_size)

    scaled_val = scaled_features[training_data_len - window_size:]
    target_val = scaled_target[training_data_len - window_size:]

    X_val, y_val = create_sliding_window(scaled_val, target_val, window_size)

    return training_data_len, X_train, y_train, X_val, y_val, target_scaler

# %%
def build_model(X_train: np.ndarray, learning_rate: float) -> keras.Model:
    """
    Builds and compiles the Deep Learning model.

    Args:
        X_train (np.ndarray): Training data.
        learning_rate (float): Learning Rate for the optimizer.

    Retruns:
        keras.Model: Compiled Keras model.
    """

    model = models.Sequential(name="ImprovedTempPredictor")
    
    model.add(layers.Input(shape=(X_train.shape[1], X_train.shape[2])))
    model.add(layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True)))
    model.add(layers.BatchNormalization())

    model.add(layers.Bidirectional(layers.LSTM(32)))
    model.add(layers.BatchNormalization())

    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(1))

    model.compile(
        optimizer=optimizers.Adam(learning_rate=learning_rate),
        loss='mae',
        metrics=['root_mean_squared_error']
    )
    
    model.summary()
    
    return model

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv("data/jena_climate_2009_2016.csv")
df = df[5::6]

date_time = pd.to_datetime(df.pop('Date Time'), format='%d.%m.%Y %H:%M:%S')

# %%
df.head()
# Out:
#     p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 17    996.84     -8.81    264.59        -9.66    93.5          3.13
# 23    996.99     -9.05    264.34       -10.02    92.6          3.07
# 29    997.46     -9.63    263.72       -10.65    92.2          2.94
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 5           3.14          0.19       1.96             3.15       1307.86
# 11          2.90          0.21       1.81             2.91       1312.25
# 17          2.93          0.20       1.83             2.94       1312.18
# 23          2.85          0.23       1.78             2.85       1313.61
# 29          2.71          0.23       1.69             2.71       1317.19
#
#     wv (m/s)  max. wv (m/s)  wd (deg)
# 5       0.21           0.63     192.7
# 11      0.25           0.63     190.3
# 17      0.18           0.63     167.2
# 23      0.10           0.38     240.0
# 29      0.40           0.88     157.0

# %% [markdown]
# ## Clean Dataset

# %%
cleaned_df = df.copy()

# Add engineered time features
cleaned_df['Month'] = date_time.dt.month
cleaned_df['Week'] = date_time.dt.isocalendar().week
cleaned_df['Year'] = date_time.dt.year
 
cleaned_df.dropna(inplace=True)

# %%
cleaned_df.head()
# Out:
#     p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 17    996.84     -8.81    264.59        -9.66    93.5          3.13
# 23    996.99     -9.05    264.34       -10.02    92.6          3.07
# 29    997.46     -9.63    263.72       -10.65    92.2          2.94
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 5           3.14          0.19       1.96             3.15       1307.86
# 11          2.90          0.21       1.81             2.91       1312.25
# 17          2.93          0.20       1.83             2.94       1312.18
# 23          2.85          0.23       1.78             2.85       1313.61
# 29          2.71          0.23       1.69             2.71       1317.19
#
#     wv (m/s)  max. wv (m/s)  wd (deg)  Month  Week  Year
# 5       0.21           0.63     192.7      1     1  2009
# 11      0.25           0.63     190.3      1     1  2009
# 17      0.18           0.63     167.2      1     1  2009
# 23      0.10           0.38     240.0      1     1  2009
# 29      0.40           0.88     157.0      1     1  2009

# %% [markdown]
# #### A very clean periodic trend can be noticed with temperature, relative humidity along the years.

# %%
plot_cols = ['T (degC)', 'p (mbar)', 'rho (g/m**3)']
plot_features = cleaned_df[plot_cols]
plot_features.index = date_time
_ = plot_features.plot(subplots=True, figsize=(10,6))

# %% [markdown]
# ## Feature Engineering

# %%
cleaned_df.describe().transpose()
# Out:
#                    count         mean        std      min      25%     50%  \
# p (mbar)         70091.0   989.212842   8.358886    913.6    984.2  989.57
# T (degC)         70091.0     9.450482   8.423384   -22.76     3.35    9.41
# Tpot (K)         70091.0   283.493086   8.504424   250.85   277.44  283.46
# Tdew (degC)      70091.0     4.956471   6.730081    -24.8     0.24    5.21
# rh (%)           70091.0    76.009788   16.47492    13.88    65.21    79.3
# VPmax (mbar)     70091.0    13.576576   7.739883     0.97     7.77   11.82
# VPact (mbar)     70091.0     9.533968   4.183658     0.81     6.22    8.86
# VPdef (mbar)     70091.0     4.042536   4.898549      0.0     0.87    2.19
# sh (g/kg)        70091.0      6.02256   2.655812     0.51     3.92    5.59
# H2OC (mmol/mol)  70091.0     9.640437   4.234862     0.81     6.29    8.96
# rho (g/m**3)     70091.0  1216.061232  39.974263  1059.45  1187.47  1213.8
# wv (m/s)         70091.0     1.702567  65.447512  -9999.0     0.99    1.76
# max. wv (m/s)    70091.0     2.963041  75.597657  -9999.0     1.76    2.98
# wd (deg)         70091.0   174.789095  86.619431      0.0    125.3   198.1
# Month            70091.0     6.517427   3.448298      1.0      4.0     7.0
# Week             70091.0    26.618211  15.060558      1.0     14.0    27.0
# Year             70091.0  2012.496826    2.28976   2009.0   2010.0  2012.0
#
#                       75%      max
# p (mbar)           994.72  1015.29
# T (degC)            15.48    37.28
# Tpot (K)           289.53   311.21
# Tdew (degC)         10.08    23.06
# rh (%)               89.4    100.0
# VPmax (mbar)        17.61    63.77
# VPact (mbar)        12.36    28.25
# VPdef (mbar)          5.3    46.01
# sh (g/kg)             7.8    18.07
# H2OC (mmol/mol)     12.49    28.74
# rho (g/m**3)     1242.765  1393.54
# wv (m/s)             2.86    14.01
# max. wv (m/s)        4.74     23.5
# wd (deg)            234.0    360.0
# Month                10.0     12.0
# Week                 40.0     53.0
# Year               2014.0   2016.0

# %%
## Remove Outlier / Erroneous Values

cleaned_df.loc[-9999.0, 'wv (m/s)'] = 0.0
cleaned_df.loc[-9999.0, 'max. wv (m/s)'] = 0.0

# %% [markdown]
# #### Since Wind Direction is in degrees, convert them Wind Velocity and Max Wind Velocity columns to vectors

# %%
wv = cleaned_df.pop('wv (m/s)')
max_wv = cleaned_df.pop('max. wv (m/s)')

# Convert to radians.
wd_rad = cleaned_df.pop('wd (deg)') * np.pi / 180

# Calculate the wind x and y components.
cleaned_df['Wx'] = wv * np.cos(wd_rad)
cleaned_df['Wy'] = wv * np.sin(wd_rad)

# Calculate the max wind x and y components.
cleaned_df['max Wx'] = max_wv * np.cos(wd_rad)
cleaned_df['max Wy'] = max_wv * np.sin(wd_rad)

# %%
cleaned_df.head()
# Out:
#     p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 17    996.84     -8.81    264.59        -9.66    93.5          3.13
# 23    996.99     -9.05    264.34       -10.02    92.6          3.07
# 29    997.46     -9.63    263.72       -10.65    92.2          2.94
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 5           3.14          0.19       1.96             3.15       1307.86
# 11          2.90          0.21       1.81             2.91       1312.25
# 17          2.93          0.20       1.83             2.94       1312.18
# 23          2.85          0.23       1.78             2.85       1313.61
# 29          2.71          0.23       1.69             2.71       1317.19
#
#     Month  Week    Year        Wx        Wy    max Wx    max Wy
# 5     1.0     1  2009.0 -0.204862 -0.046168 -0.614587 -0.138503
# 11    1.0     1  2009.0 -0.245971 -0.044701 -0.619848 -0.112645
# 17    1.0     1  2009.0 -0.175527  0.039879 -0.614344  0.139576
# 23    1.0     1  2009.0 -0.050000 -0.086603 -0.190000 -0.329090
# 29    1.0     1  2009.0 -0.368202  0.156292 -0.810044  0.343843

# %% [markdown]
# #### Similarly convert Day and Year columns to vectors

# %%
timestamp_s = date_time.map(pd.Timestamp.timestamp)

day = 24*60*60
year = (365.2425)*day

cleaned_df['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
cleaned_df['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
cleaned_df['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
cleaned_df['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

# %%
cleaned_df.head()
# Out:
#     p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 17    996.84     -8.81    264.59        -9.66    93.5          3.13
# 23    996.99     -9.05    264.34       -10.02    92.6          3.07
# 29    997.46     -9.63    263.72       -10.65    92.2          2.94
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  ...  Week    Year  \
# 5           3.14          0.19       1.96             3.15  ...     1  2009.0
# 11          2.90          0.21       1.81             2.91  ...     1  2009.0
# 17          2.93          0.20       1.83             2.94  ...     1  2009.0
# 23          2.85          0.23       1.78             2.85  ...     1  2009.0
# 29          2.71          0.23       1.69             2.71  ...     1  2009.0
#
#           Wx        Wy    max Wx    max Wy   Day sin   Day cos  Year sin  \
# 5  -0.204862 -0.046168 -0.614587 -0.138503  0.258819  0.965926  0.010049
# 11 -0.245971 -0.044701 -0.619848 -0.112645  0.500000  0.866025  0.010766
# 17 -0.175527  0.039879 -0.614344  0.139576  0.707107  0.707107  0.011483
# 23 -0.050000 -0.086603 -0.190000 -0.329090  0.866025  0.500000  0.012199
# 29 -0.368202  0.156292 -0.810044  0.343843  0.965926  0.258819  0.012916
#
#     Year cos
# 5   0.999950
# 11  0.999942
# 17  0.999934
# 23  0.999926
# 29  0.999917
#
# [5 rows x 22 columns]

# %%
plt.plot(cleaned_df['Day sin'][:25])
plt.plot(cleaned_df['Day cos'][:25])
plt.xlabel('Time [h]')
plt.title('Time of day signal')
# Out:
# Text(0.5, 1.0, 'Time of day signal')

# %%
cleaned_df.dropna(inplace=True)
cleaned_df.isna().sum()
# Out:
# p (mbar)           0
# T (degC)           0
# Tpot (K)           0
# Tdew (degC)        0
# rh (%)             0
# VPmax (mbar)       0
# VPact (mbar)       0
# VPdef (mbar)       0
# sh (g/kg)          0
# H2OC (mmol/mol)    0
# rho (g/m**3)       0
# Month              0
# Week               0
# Year               0
# Wx                 0
# Wy                 0
# max Wx             0
# max Wy             0
# Day sin            0
# Day cos            0
# Year sin           0
# Year cos           0
# dtype: int64

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Create Train and Validation Datasets

# %%
training_data_len, X_train, y_train, X_val, y_val, target_scaler = prepare_train_test_datasets(cleaned_df, 0.2, 12)

# %%
# Hyperparameters
batch_size = 128
epochs = 100
learning_rate = 0.001

# Build model
model = build_model(X_train, learning_rate)

# Early stopping to avoid overfitting
early_stop = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Reduce learning rate to avoid overshooting and plateuing
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1,
    min_lr=1e-6
)

# Fit model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop, reduce_lr],
    verbose=2
)
# Out:
# I0000 00:00:1747946805.822500      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1747946805.823141      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "ImprovedTempPredictor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 12, 64)              │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 12, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 12, 128)             │          66,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 12, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 116,609 (455.50 KB)
#  Trainable params: 116,097 (453.50 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/100
# I0000 00:00:1747946814.297433      85 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 438/438 - 15s - 35ms/step - loss: 0.2497 - root_mean_squared_error: 0.3481 - val_loss: 0.1327 - val_root_mean_squared_error: 0.1723 - learning_rate: 0.0010
# Epoch 2/100
# 438/438 - 5s - 12ms/step - loss: 0.1584 - root_mean_squared_error: 0.2092 - val_loss: 0.1093 - val_root_mean_squared_error: 0.1403 - learning_rate: 0.0010
# Epoch 3/100
# 438/438 - 5s - 12ms/step - loss: 0.1477 - root_mean_squared_error: 0.1971 - val_loss: 0.0978 - val_root_mean_squared_error: 0.1286 - learning_rate: 0.0010
# Epoch 4/100
# 438/438 - 5s - 12ms/step - loss: 0.1357 - root_mean_squared_error: 0.1824 - val_loss: 0.0793 - val_root_mean_squared_error: 0.1056 - learning_rate: 0.0010
# Epoch 5/100
# 438/438 - 5s - 12ms/step - loss: 0.1314 - root_mean_squared_error: 0.1779 - val_loss: 0.0959 - val_root_mean_squared_error: 0.1292 - learning_rate: 0.0010
# Epoch 6/100
# 438/438 - 5s - 12ms/step - loss: 0.1269 - root_mean_squared_error: 0.1729 - val_loss: 0.0706 - val_root_mean_squared_error: 0.0967 - learning_rate: 0.0010
# Epoch 7/100
# 438/438 - 5s - 12ms/step - loss: 0.1234 - root_mean_squared_error: 0.1692 - val_loss: 0.0668 - val_root_mean_squared_error: 0.0917 - learning_rate: 0.0010
# Epoch 8/100
# 438/438 - 5s - 12ms/step - loss: 0.1209 - root_mean_squared_error: 0.1661 - val_loss: 0.0688 - val_root_mean_squared_error: 0.0949 - learning_rate: 0.0010
# Epoch 9/100
# 438/438 - 5s - 12ms/step - loss: 0.1173 - root_mean_squared_error: 0.1616 - val_loss: 0.0714 - val_root_mean_squared_error: 0.0977 - learning_rate: 0.0010
# Epoch 10/100
# 438/438 - 5s - 12ms/step - loss: 0.1176 - root_mean_squared_error: 0.1620 - val_loss: 0.0693 - val_root_mean_squared_error: 0.0939 - learning_rate: 0.0010
# Epoch 11/100
# 438/438 - 5s - 12ms/step - loss: 0.1166 - root_mean_squared_error: 0.1612 - val_loss: 0.0630 - val_root_mean_squared_error: 0.0882 - learning_rate: 0.0010
# Epoch 12/100
# 438/438 - 5s - 12ms/step - loss: 0.1157 - root_mean_squared_error: 0.1599 - val_loss: 0.0682 - val_root_mean_squared_error: 0.0931 - learning_rate: 0.0010
# Epoch 13/100
# 438/438 - 5s - 12ms/step - loss: 0.1145 - root_mean_squared_error: 0.1587 - val_loss: 0.0633 - val_root_mean_squared_error: 0.0878 - learning_rate: 0.0010
# Epoch 14/100
# 438/438 - 5s - 12ms/step - loss: 0.1125 - root_mean_squared_error: 0.1560 - val_loss: 0.0633 - val_root_mean_squared_error: 0.0889 - learning_rate: 0.0010
# Epoch 15/100
# 438/438 - 5s - 12ms/step - loss: 0.1120 - root_mean_squared_error: 0.1552 - val_loss: 0.0702 - val_root_mean_squared_error: 0.0972 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 438/438 - 5s - 12ms/step - loss: 0.1115 - root_mean_squared_error: 0.1551 - val_loss: 0.0638 - val_root_mean_squared_error: 0.0879 - learning_rate: 0.0010
# Epoch 17/100
# 438/438 - 5s - 12ms/step - loss: 0.1070 - root_mean_squared_error: 0.1496 - val_loss: 0.0718 - val_root_mean_squared_error: 0.0973 - learning_rate: 5.0000e-04
# Epoch 18/100
# 438/438 - 5s - 12ms/step - loss: 0.1060 - root_mean_squared_error: 0.1477 - val_loss: 0.0573 - val_root_mean_squared_error: 0.0822 - learning_rate: 5.0000e-04
# Epoch 19/100
# 438/438 - 5s - 12ms/step - loss: 0.1058 - root_mean_squared_error: 0.1480 - val_loss: 0.0584 - val_root_mean_squared_error: 0.0838 - learning_rate: 5.0000e-04
# Epoch 20/100
# 438/438 - 5s - 12ms/step - loss: 0.1059 - root_mean_squared_error: 0.1483 - val_loss: 0.0682 - val_root_mean_squared_error: 0.0949 - learning_rate: 5.0000e-04
# Epoch 21/100
# 438/438 - 5s - 12ms/step - loss: 0.1050 - root_mean_squared_error: 0.1469 - val_loss: 0.0671 - val_root_mean_squared_error: 0.0910 - learning_rate: 5.0000e-04
# Epoch 22/100
# 438/438 - 5s - 12ms/step - loss: 0.1045 - root_mean_squared_error: 0.1465 - val_loss: 0.0604 - val_root_mean_squared_error: 0.0857 - learning_rate: 5.0000e-04
# Epoch 23/100
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 438/438 - 5s - 12ms/step - loss: 0.1040 - root_mean_squared_error: 0.1458 - val_loss: 0.0635 - val_root_mean_squared_error: 0.0893 - learning_rate: 5.0000e-04
# Epoch 24/100
# 438/438 - 5s - 12ms/step - loss: 0.1016 - root_mean_squared_error: 0.1427 - val_loss: 0.0633 - val_root_mean_squared_error: 0.0878 - learning_rate: 2.5000e-04
# Epoch 25/100
# 438/438 - 5s - 12ms/step - loss: 0.1017 - root_mean_squared_error: 0.1430 - val_loss: 0.0666 - val_root_mean_squared_error: 0.0924 - learning_rate: 2.5000e-04
# Epoch 26/100
# 438/438 - 5s - 12ms/step - loss: 0.1016 - root_mean_squared_error: 0.1428 - val_loss: 0.0554 - val_root_mean_squared_error: 0.0812 - learning_rate: 2.5000e-04
# Epoch 27/100
# 438/438 - 5s - 12ms/step - loss: 0.1015 - root_mean_squared_error: 0.1432 - val_loss: 0.0576 - val_root_mean_squared_error: 0.0828 - learning_rate: 2.5000e-04
# Epoch 28/100
# 438/438 - 5s - 12ms/step - loss: 0.1019 - root_mean_squared_error: 0.1435 - val_loss: 0.0578 - val_root_mean_squared_error: 0.0835 - learning_rate: 2.5000e-04
# Epoch 29/100
# 438/438 - 5s - 12ms/step - loss: 0.1012 - root_mean_squared_error: 0.1425 - val_loss: 0.0570 - val_root_mean_squared_error: 0.0821 - learning_rate: 2.5000e-04
# Epoch 30/100
# 438/438 - 5s - 12ms/step - loss: 0.1015 - root_mean_squared_error: 0.1427 - val_loss: 0.0654 - val_root_mean_squared_error: 0.0900 - learning_rate: 2.5000e-04
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 438/438 - 5s - 12ms/step - loss: 0.1014 - root_mean_squared_error: 0.1427 - val_loss: 0.0626 - val_root_mean_squared_error: 0.0868 - learning_rate: 2.5000e-04
# Epoch 32/100
# 438/438 - 5s - 12ms/step - loss: 0.1002 - root_mean_squared_error: 0.1416 - val_loss: 0.0646 - val_root_mean_squared_error: 0.0893 - learning_rate: 1.2500e-04
# Epoch 33/100
# 438/438 - 5s - 12ms/step - loss: 0.1002 - root_mean_squared_error: 0.1413 - val_loss: 0.0662 - val_root_mean_squared_error: 0.0900 - learning_rate: 1.2500e-04
# Epoch 34/100
# 438/438 - 5s - 12ms/step - loss: 0.1001 - root_mean_squared_error: 0.1412 - val_loss: 0.0608 - val_root_mean_squared_error: 0.0856 - learning_rate: 1.2500e-04
# Epoch 35/100
# 438/438 - 5s - 12ms/step - loss: 0.0996 - root_mean_squared_error: 0.1405 - val_loss: 0.0645 - val_root_mean_squared_error: 0.0900 - learning_rate: 1.2500e-04
# Epoch 36/100
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 438/438 - 5s - 12ms/step - loss: 0.0997 - root_mean_squared_error: 0.1404 - val_loss: 0.0554 - val_root_mean_squared_error: 0.0808 - learning_rate: 1.2500e-04
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.

# %% [markdown]
# ## Training History and Prediction Graphs

# %%
def generate_history_graph(history: dict) -> None:
    """
        Plots History Graph.

        Args:
            history (dict): History Dictionary from Keras model training.

        Returns:
            None
    """

    metrics = list(history.history.keys())
    num_metrics = len(metrics)
    cols = 2
    rows = math.ceil(num_metrics / cols)

    plt.figure(figsize=(8 * cols, 6 * rows))

    for idx, metric in enumerate(metrics, 1):
        plt.subplot(rows, cols, idx)
        plt.plot(history.history[metric], label=metric)
        plt.title(f"{metric} over Epochs")
        plt.xlabel('Epochs')
        plt.ylabel(metric)
        plt.legend()
        plt.grid(True)

    plt.tight_layout()
    plt.show()

generate_history_graph(history)

# %%
def generate_prediction_graph(X_val: np.ndarray, y_val: np.ndarray) -> None:
    """
        Plots Prediction Graph.

        Args:
            X_val & y_val (np.ndarray): Validation features and target data.

        Returns:
            None
    """

    y_pred_scaled = model.predict(X_val)

    # 2. Inverse scale to original units
    y_pred = target_scaler.inverse_transform(y_pred_scaled)
    y_true = target_scaler.inverse_transform(y_val)
    
    # 3. Plot first 100 samples or full range
    plt.figure(figsize=(12,6))
    plt.plot(y_true[::250], label='Actual Temperature')
    plt.plot(y_pred[::250], label='Predicted Temperature')
    plt.xlabel('Time Step')
    plt.ylabel('Temperature (°C)')
    plt.title('Actual vs Predicted Temperature on Validation Set')
    plt.legend()
    plt.show()

    return y_pred, y_true


y_pred, y_true = generate_prediction_graph(X_val, y_val)
# Out:
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step

# %%
comparison_array = np.concatenate([y_true[::20], y_pred[::20]], axis=1)
comparison_df = pd.DataFrame(comparison_array, columns=['Actual_Temperature', 'Predicted_Temperature'])

# %%
comparison_df.head()
# Out:
#    Actual_Temperature  Predicted_Temperature
# 0               16.92              16.858084
# 1               15.48              16.894194
# 2               13.04              12.469452
# 3               10.39               9.676424
# 4                4.63               5.044060

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
# MAE: 0.4668
# RMSE: 0.6843

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_true, y_pred)
print(f"R^2 score: {r2:.4f}")
# Out:
# R^2 score: 0.9928

# %% [markdown]
# ## Save Model

# %%
model.save('TempPredictor.keras')
