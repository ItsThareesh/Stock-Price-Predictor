# %%
import tensorflow as tf

import keras
from keras import models
from keras import layers

from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Configs

# %%
tf.random.set_seed(96)

dataset_path = "data/TSLA.csv"
train_test_split = 0.95
window_size = 60
batch_size = 32
epochs = 25

open_column = "Open"
close_column = "Close"
date_column = "Date"
high_column = "High"
low_column = "Low"
volume_column = "Volume"

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv(dataset_path)
df.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df[date_column] = pd.to_datetime(df[date_column])

# %% [markdown]
# ## Graphs and Correlation Matrix

# %%
plt.figure(figsize=(12, 6))
plt.title('Microsoft: Stock Prices')
plt.plot(df[date_column], df[open_column], label='Open Price')
plt.plot(df[date_column], df[close_column], label='Close Price')
plt.xlabel(date_column)
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.title('Tesla: Highest and Lowest Prices')
plt.plot(df[date_column], df[high_column], label='Highest Price')
plt.plot(df[date_column], df[low_column], label='Lowest Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.title('Tesla: Trade Volume')
plt.plot(df[date_column], df[volume_column], label='Volume')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
numeric_df.head()
# Out:
#     Open   High    Low  Close  Adj Close    Volume
# 0  3.800  5.000  3.508  4.778      4.778  93831500
# 1  5.158  6.084  4.660  4.766      4.766  85935500
# 2  5.000  5.184  4.054  4.392      4.392  41094000
# 3  4.600  4.620  3.742  3.840      3.840  25699000
# 4  4.000  4.000  3.166  3.222      3.222  34334500

# %%
plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='inferno')
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scale Data

# %%
stock_close = df[close_column].values

# %%
training_data_len = int(np.ceil(train_test_split * len(stock_close)))

dataset = stock_close.reshape(-1, 1)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(dataset)

scaled_train = scaled_data[:training_data_len]

# %%
scaled_train.shape
# Out:
# (2809, 1)

# %% [markdown]
# ## Provide Context to train LSTM

# %%
def create_sliding_window(data, window_size):
    X, y = [], []
    
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    
    return np.array(X), np.array(y).reshape(-1)

# %%
X_train, y_train = create_sliding_window(scaled_train, window_size)

# %%
X_train.shape, y_train.shape
# Out:
# ((2749, 60, 1), (2749,))

# %% [markdown]
# ## Build Model

# %%
model = models.Sequential(name="StockPriceLSTM")
model.add(keras.Input(shape=(X_train.shape[1], X_train.shape[2])))
model.add(layers.LSTM(64, return_sequences=True))
model.add(layers.LSTM(64, return_sequences=False))
model.add(layers.Dense(128, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1))
model.summary()
model.compile(optimizer="adam", loss="mae", metrics=["root_mean_squared_error"])
# Out:
# Model: "StockPriceLSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,369 (228.00 KB)
#  Trainable params: 58,369 (228.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train Model

# %%
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 0.2002 - root_mean_squared_error: 0.3435
# Epoch 2/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0818 - root_mean_squared_error: 0.1461
# Epoch 3/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0754 - root_mean_squared_error: 0.1431
# Epoch 4/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0694 - root_mean_squared_error: 0.1246
# Epoch 5/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0657 - root_mean_squared_error: 0.1219
# Epoch 6/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0640 - root_mean_squared_error: 0.1224
# Epoch 7/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0623 - root_mean_squared_error: 0.1221
# Epoch 8/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0594 - root_mean_squared_error: 0.1207
# Epoch 9/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0596 - root_mean_squared_error: 0.1245
# Epoch 10/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0536 - root_mean_squared_error: 0.1148
# Epoch 11/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0569 - root_mean_squared_error: 0.1296
# Epoch 12/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0483 - root_mean_squared_error: 0.1057
# Epoch 13/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0476 - root_mean_squared_error: 0.1068
# Epoch 14/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0478 - root_mean_squared_error: 0.1096
# Epoch 15/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0458 - root_mean_squared_error: 0.1059
# Epoch 16/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0425 - root_mean_squared_error: 0.0971
# Epoch 17/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0451 - root_mean_squared_error: 0.1159
# Epoch 18/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0472 - root_mean_squared_error: 0.1231
# Epoch 19/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0433 - root_mean_squared_error: 0.1112
# Epoch 20/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0410 - root_mean_squared_error: 0.1037
# Epoch 21/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0416 - root_mean_squared_error: 0.1066
# Epoch 22/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0435 - root_mean_squared_error: 0.1120
# Epoch 23/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0422 - root_mean_squared_error: 0.1061
# Epoch 24/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0431 - root_mean_squared_error: 0.1100
# Epoch 25/25
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0389 - root_mean_squared_error: 0.0985

# %% [markdown]
# ## Training History Graphs

# %%
def generate_history_graph(history):
    metrics = list(history.history.keys())
    num_metrics = len(metrics)
    
    plt.figure(figsize=(8*num_metrics, 6))
    
    for idx, metric in enumerate(metrics, 1):
        plt.subplot(1, num_metrics, idx)
        plt.plot(history.history[metric], label=metric)
        plt.title(f"{metric} over Epochs")
        plt.xlabel('Epochs')
        plt.ylabel(metric)
        plt.legend()
        plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %%
generate_history_graph(history)

# %% [markdown]
# ## Save Model

# %%
model.save("StockPriceLSTM.keras")

# %% [markdown]
# ## Model Testing

# %% [markdown]
# ### Prepare X_test

# %%
test_data = scaled_data[training_data_len - window_size:]  # Start from training_data_len - window_size because that's where X_train ends

X_test, _ = create_sliding_window(test_data, window_size)

# %%
len(test_data), X_test.shape
# Out:
# (207, (147, 60, 1))

# %% [markdown]
# ### Prediction

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %% [markdown]
# ### Visualization

# %%
train = df[:training_data_len]
test = df[training_data_len:].copy() # Start from training_data_len because that's where your predictions start from
test['Predictions'] = predictions

plt.figure(figsize=(20, 8))

# Full View
plt.subplot(1, 2, 1)
plt.plot(train[date_column], train[close_column], label="Train", color='green')
plt.plot(test[date_column], test[close_column], label="Test (Actual)", color='orange')
plt.plot(test[date_column], test['Predictions'], label="Predictions", color='red', alpha=0.65)
plt.title("Stock Predictions - Full")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()

# Zoomed View: Test vs Predictions
plt.subplot(1, 2, 2)
plt.plot(test[date_column], test[close_column], label="Test (Actual)", color='orange')
plt.plot(test[date_column], test['Predictions'], label="Predictions", color='red', alpha=0.65)
plt.title("Stock Predictions - Zoomed Test Set")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()

plt.tight_layout()
plt.show()
